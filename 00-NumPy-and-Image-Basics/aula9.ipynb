# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
pic = Image.open('../DATA/00-puppy.jpg')

# %%
type(pic)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
pic
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1950x1300 at 0x739F2B0>

# %%
pic_arr = np.asarray(pic)

# %%
type(pic_arr)
# Out:
# numpy.ndarray

# %%
pic_arr.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(pic_arr)

# %%
#RED
plt.imshow(pic_arr[400:800,750:1500,0], cmap='gray')

# %%
#GREEN
plt.imshow(pic_arr[400:800,750:1500,1], cmap='gray')

# %%
#BLUE
plt.imshow(pic_arr[400:800,750:1500,2], cmap='gray')

# %%
pic_arr[400:800,750:1500,1] =0
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-00c81fe0251a> in <module>()
# ----> 1 pic_arr[400:800,750:1500,1] =0
#
# ValueError: assignment destination is read-only

# %%
pic_red = pic_arr.copy()

# %%
plt.imshow(pic_red[400:800,750:1500,2], cmap='gray')

# %%
pic_red[400:800,750:1500,2] = 0

# %%
pic_red[400:800,750:1500,2] = 0

# %%
pic_red[400:800,750:1500,2] = 70

# %%
plt.imshow(pic_red[:,:,1])

# %%
pic_red
# Out:
# array([[[95, 81, 78],
#         [97, 83, 80],
#         [98, 84, 81],
#         ...,
#         [25, 27, 22],
#         [25, 27, 22],
#         [25, 27, 22]],
#
#        [[95, 81, 78],
#         [96, 82, 79],
#         [96, 82, 79],
#         ...,
#         [25, 27, 22],
#         [25, 27, 22],
#         [25, 27, 22]],
#
#        [[95, 81, 78],
#         [94, 80, 77],
#         [94, 80, 77],
#         ...,
#         [25, 27, 22],
#         [25, 27, 22],
#         [25, 27, 22]],
#
#        ...,
#
#        [[19, 29, 20],
#         [20, 30, 21],
#         [20, 30, 21],
#         ...,
#         [23, 30, 22],
#         [24, 31, 23],
#         [24, 31, 23]],
#
#        [[20, 30, 21],
#         [20, 30, 21],
#         [19, 29, 20],
#         ...,
#         [23, 30, 22],
#         [24, 31, 23],
#         [24, 31, 23]],
#
#        [[20, 30, 21],
#         [19, 29, 20],
#         [19, 29, 20],
#         ...,
#         [23, 30, 22],
#         [24, 31, 23],
#         [24, 31, 23]]], dtype=uint8)
