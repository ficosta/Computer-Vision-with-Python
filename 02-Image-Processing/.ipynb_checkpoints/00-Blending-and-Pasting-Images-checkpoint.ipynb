# %% [markdown]
# <a href="https://www.pieriandata.com"><img src="../DATA/Logo.jpg"></a>
#
# # Blending and Pasting Images
#
# For some computer vision systems, we'll want to be able to post our own image on top of an already existing image or video. We may also want to blend images, maybe we want to have a "highlight" effect instead of just a solid box or empty rectangle.
#
# Let's explore what is commonly known as **Arithmetic Image Operations** with OpenCV. These are referred to as Arithmetic Operations because OpenCV is simply performing some common math with the pixels for the final effect. We'll see a bit of this in our code.
#
# ## Blending Images
#
# Blending Images is actually quite simple, let's look at a simple example.

# %%
import cv2

# %%
# Two images
img1 = cv2.imread('../DATA/dog_backpack.jpg')
img2 = cv2.imread('../DATA/watermark_no_copy.png')

# %%
img1.shape
# Out:
# (1401, 934, 3)

# %%
img2.shape
# Out:
# (1280, 1277, 3)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(img1)

# %% [markdown]
# Whoops! Let's remember to fix the RGB!

# %%
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %% [markdown]
# ### Resizing the Images

# %%
img1 =cv2.resize(img1,(1200,1200))
img2 =cv2.resize(img2,(1200,1200))

# %% [markdown]
# Let's practice resizing the image, since the DO NOT COPY image is actually quite large 1200 by 1200, and our puppy in backpack image is 1400 by 1000

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %% [markdown]
# ### Blending the Image
#
# We will blend the values together with the formula:
#
# $$  img1 * \alpha  + img2 * \beta  + \gamma $$

# %%
img1.shape
# Out:
# (1200, 1200, 3)

# %%
img2.shape
# Out:
# (1200, 1200, 3)

# %%
blended = cv2.addWeighted(src1=img1,alpha=0.7,src2=img2,beta=0.3,gamma=0)

# %%
plt.imshow(blended)

# %% [markdown]
# ## Pasting Images and Masks
#
# Let's imagine we wanted to automatically watermark some images. We wouldn't want to have to reshape the images everytime! Maybe we also want to mask a certain color, such as everything that was white in the DO NOT COPY image.
#
# Let's take a look again!
#
# Let's open two images again to start from scratch:

# %%
img1 = cv2.imread('../DATA/dog_backpack.jpg')
img2 = cv2.imread('../DATA/watermark_no_copy.png')

# %%
img1 = cv2.cvtColor(img1, cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

# %%
img1.shape
# Out:
# (1401, 934, 3)

# %%
img2.shape
# Out:
# (1280, 1277, 3)

# %% [markdown]
# Let's make the second image smaller, so we can stick it in the top left corner.

# %%
img2 =cv2.resize(img2,(600,600))

# %%
rows,cols, channels = img2.shape

# %%
rows
# Out:
# 600

# %%
cols
# Out:
# 600

# %%
channels
# Out:
# 3

# %%
# Notice the 255,255,255 values, those are white! 
# We may want to remove those later or change their values!
img2
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]]], dtype=uint8)

# %% [markdown]
# Now we mark the "Region of Interest" or ROI in the puppy image. Basically, where we want the watermark to go.

# %%
# Notice this is on IMAGE 1
roi = img1[0:rows, 0:cols ]

# %%
plt.imshow(roi)

# %% [markdown]
# Now we will create a mask of the watermark.

# %%
# Now create a mask of logo and create its inverse mask also
img2gray = cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
ret, mask = cv2.threshold(img2gray, 10, 255, cv2.THRESH_BINARY)
mask_inv = cv2.bitwise_not(mask)

# Now black-out the area of logo in ROI
img1_bg = cv2.bitwise_and(roi,roi,mask = mask_inv)

# Take only region of logo from logo image.
img2_fg = cv2.bitwise_and(img2,img2,mask = mask)

# Put logo in ROI and modify the main image
dst = cv2.add(img1_bg,img2_fg)
img1[0:rows, 0:cols ] = dst

plt.imshow(img1)

# %%
import numpy as np
# img1 == [255,255,255]

# %%
img1[np.where(img1 == [255])] = [0]

# %%
plt.imshow(img1)

# %%
img1[img1 == [[255,255,255]] ] = [[0,0,0]]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-123-18ea83e3d12b> in <module>()
# ----> 1 img1[img1 == [[255,255,255]] ] = [[0,0,0]]
#
# TypeError: NumPy boolean array indexing assignment requires a 0 or 1-dimensional input, input has 2 dimensions
