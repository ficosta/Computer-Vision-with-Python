# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
raimbow = cv2.imread('../DATA/rainbow.jpg1')
show_raimbow = cv2.cvtColor(raimbow, cv2.COLOR_BGR2RGB)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-23-e401ad04a26f> in <module>()
#       1 raimbow = cv2.imread('../DATA/rainbow.jpg1')
# ----> 2 show_raimbow = cv2.cvtColor(raimbow, cv2.COLOR_BGR2RGB)
#
# error: OpenCV(3.4.2) /opt/concourse/worker/volumes/live/0851a95b-0a19-4f3a-61a7-502b925fea13/volume/opencv-suite_1535642710601/work/modules/imgproc/src/color.hpp:253: error: (-215:Assertion failed) VScn::contains(scn) && VDcn::contains(dcn) && VDepth::contains(depth) in function 'CvtHelper'

# %%
img = raimbow
type(img)
# Out:
# NoneType

# %%
img.shape
# Out:
# (550, 413, 3)

# %%
mask = np.zeros(img.shape[:2], np.uint8)

# %%
mask[300:400, 100:400] = 255

# %%
plt.imshow(mask, cmap='gray')

# %%
mask_img = cv2.bitwise_and(img, img, mask = mask)

# %%
show_masked_img = cv2.bitwise_and(show_raimbow, show_raimbow, mask= mask)

# %%
plt.imshow(show_masked_img)

# %%
hist_mask_values_red = cv2.calcHist([raimbow], channels=[2], mask=mask, histSize=[256], ranges=[0,256])

# %%
plt.plot(hist_mask_values_red)
plt.title('RED HISTOGRAM FOR MASKED RAINBOW')
# Out:
# Text(0.5,1,'RED HISTOGRAM FOR MASKED RAINBOW')

# %%
hist_mask_values_red = cv2.calcHist([raimbow], channels=[2], mask=None, histSize=[256], ranges=[0,256])
plt.plot(hist_mask_values_red)
plt.title('RED HISTOGRAM FOR RAINBOW')
# Out:
# Text(0.5,1,'RED HISTOGRAM FOR RAINBOW')

# %%
gorilla = cv2.imread('../DATA/gorilla.jpg',0)

# %%
def display(img,cmap=None):
    fig = plt.figure(figsize=(10,8))
    ax = fig.add_subplot(111)
    ax.imshow(img,cmap)

# %%
display(gorilla, cmap='gray')

# %%
gorilla.shape
# Out:
# (1295, 1955)

# %%
hist_values = cv2.calcHist([gorilla], channels=[0], mask=None, histSize=[256], ranges=[0,256])

# %%
plt.plot(hist_values)

# %%
eq_gorilla = cv2.equalizeHist(gorilla)

# %%
display(eq_gorilla, cmap='gray')

# %%
hist_values = cv2.calcHist([eq_gorilla], channels=[0], mask=None, histSize=[256], ranges=[0,256])

# %%
plt.plot(hist_values)

# %%
color_gorila= cv2.imread('../DATA/gorilla.jpg')

# %%
show_gorila = cv2.cvtColor(color_gorila, cv2.COLOR_BGR2RGB)

# %%
display(show_gorila)

# %%
hsv = cv2.cvtColor(color_gorila, cv2.COLOR_BGR2HSV)

# %%
hsv[:,:,2] = cv2.equalizeHist(hsv[:,:,2])

# %%
rgb = cv2.cvtColor(hsv, cv2.COLOR_HSV2RGB)

# %%
plt.imshow(rgb)
